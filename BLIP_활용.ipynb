# %% [markdown]
# # BLIP 활용한 레이블링

# %%
# !pip install ultralytics
# Out:
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# Requirement already satisfied: ultralytics in /Users/brad/.pyenv/versions/3.12.0/lib/python3.12/site-packages (8.3.162)
# Requirement already satisfied: numpy>=1.23.0 in /Users/brad/.pyenv/versions/3.12.0/lib/python3.12/site-packages (from ultralytics) (1.26.1)
# Requirement already satisfied: matplotlib>=3.3.0 in /Users/brad/.pyenv/versions/3.12.0/lib/python3.12/site-packages (from ultralytics) (3.8.0)
# Requirement already satisfied: opencv-python>=4.6.0 in /Users/brad/.pyenv/versions/3.12.0/lib/python3.12/site-packages (from ultralytics) (4.9.0.80)
# Requirement already satisfied: pillow>=7.1.2 in /Users/brad/.pyenv/versions/3.12.0/lib/python3.12/site-packages (from ultralytics) (10.1.0)
# Requirement already satisfied: pyyaml>=5.3.1 in /Users/brad/.local/lib/python3.12/site-packages (from ultralytics) (6.0.1)
# Requirement already satisfied: requests>=2.23.0 in /Users/brad/.pyenv/versions/3.12.0/lib/python3.12/site-packages (from ultralytics) (2.31.0)
# Requirement already satisfied: scipy>=1.4.1 in /Users/brad/.pyenv/versions/3.12.0/lib/python3.12/site-packages (from ultralytics) (1.11.4)
# Requirement already satisfied: torch>=1.8.0 in /Users/brad/.pyenv/versions/3.12.0/lib/python3.12/site-packages (from ultralytics) (2.2.2)
# Requirement already satisfied: torchvision>=0.9.0 in /Users/brad/.pyenv/versions/3.12.0/lib/python3.12/site-packages (from ultralytics) (0.17.2)
# Requirement already satisfied: tqdm>=4.64.0 in /Users/brad/.pyenv/versions/3.12.0/lib/python3.12/site-packages (from ultralytics) (4.66.1)
# Requirement already satisfied: psutil in /Users/brad/.pyenv/versions/3.12.0/lib/python3.12/site-packages (from ultralytics) (5.9.6)
# Requirement already satisfied: py-cpuinfo in /Users/brad/.pyenv/versions/3.12.0/lib/python3.12/site-packages (from ultralytics) (9.0.0)
# Requirement already satisfied: pandas>=1.1.4 in /Users/brad/.pyenv/versions/3.12.0/lib/python3.12/site-packages (from ultralytics) (2.3.0)
# Requirement already satisfied: ultralytics-thop>=2.0.0 in /Users/brad/.pyenv/versions/3.12.0/lib/python3.12/site-packages (from ultralytics) (2.0.14)
# Requirement already satisfied: contourpy>=1.0.1 in /Users/brad/.pyenv/versions/3.12.0/lib/python3.12/site-packages (from matplotlib>=3.3.0->ultralytics) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in /Users/brad/.pyenv/versions/3.12.0/lib/python3.12/site-packages (from matplotlib>=3.3.0->ultralytics) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /Users/brad/.pyenv/versions/3.12.0/lib/python3.12/site-packages (from matplotlib>=3.3.0->ultralytics) (4.43.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in /Users/brad/.pyenv/versions/3.12.0/lib/python3.12/site-packages (from matplotlib>=3.3.0->ultralytics) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in /Users/brad/.pyenv/versions/3.12.0/lib/python3.12/site-packages (from matplotlib>=3.3.0->ultralytics) (25.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /Users/brad/.pyenv/versions/3.12.0/lib/python3.12/site-packages (from matplotlib>=3.3.0->ultralytics) (3.1.1)
# Requirement already satisfied: python-dateutil>=2.7 in /Users/brad/.pyenv/versions/3.12.0/lib/python3.12/site-packages (from matplotlib>=3.3.0->ultralytics) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /Users/brad/.pyenv/versions/3.12.0/lib/python3.12/site-packages (from pandas>=1.1.4->ultralytics) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.7 in /Users/brad/.pyenv/versions/3.12.0/lib/python3.12/site-packages (from pandas>=1.1.4->ultralytics) (2023.4)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/brad/.pyenv/versions/3.12.0/lib/python3.12/site-packages (from requests>=2.23.0->ultralytics) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /Users/brad/.pyenv/versions/3.12.0/lib/python3.12/site-packages (from requests>=2.23.0->ultralytics) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/brad/.local/lib/python3.12/site-packages (from requests>=2.23.0->ultralytics) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/brad/.pyenv/versions/3.12.0/lib/python3.12/site-packages (from requests>=2.23.0->ultralytics) (2023.11.17)
# Requirement already satisfied: filelock in /Users/brad/.pyenv/versions/3.12.0/lib/python3.12/site-packages (from torch>=1.8.0->ultralytics) (3.13.1)
# Requirement already satisfied: typing-extensions>=4.8.0 in /Users/brad/.pyenv/versions/3.12.0/lib/python3.12/site-packages (from torch>=1.8.0->ultralytics) (4.14.0)
# Requirement already satisfied: sympy in /Users/brad/.pyenv/versions/3.12.0/lib/python3.12/site-packages (from torch>=1.8.0->ultralytics) (1.12)
# Requirement already satisfied: networkx in /Users/brad/.pyenv/versions/3.12.0/lib/python3.12/site-packages (from torch>=1.8.0->ultralytics) (3.3)
# Requirement already satisfied: jinja2 in /Users/brad/.local/lib/python3.12/site-packages (from torch>=1.8.0->ultralytics) (3.1.2)
# Requirement already satisfied: fsspec in /Users/brad/.pyenv/versions/3.12.0/lib/python3.12/site-packages (from torch>=1.8.0->ultralytics) (2025.3.0)
# Requirement already satisfied: six>=1.5 in /Users/brad/.pyenv/versions/3.12.0/lib/python3.12/site-packages (from python-dateutil>=2.7->matplotlib>=3.3.0->ultralytics) (1.16.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /Users/brad/.local/lib/python3.12/site-packages (from jinja2->torch>=1.8.0->ultralytics) (2.1.3)
# Requirement already satisfied: mpmath>=0.19 in /Users/brad/.pyenv/versions/3.12.0/lib/python3.12/site-packages (from sympy->torch>=1.8.0->ultralytics) (1.3.0)
#
# [notice] A new release of pip is available: 25.0.1 -> 25.1.1
# [notice] To update, run: pip install --upgrade pip

# %% [markdown]
# ### 2. YOLO와 BLIP 를 다운 받기

# %%
from PIL import Image
from ultralytics import YOLO
from transformers.pipelines import pipeline
import torch

# %%
device = torch.device("cpu")  # stays on CPU
dtype = torch.float32          # avoid float16

# %%
# Load pretrained model
model = YOLO("yolo11n.pt")
# Out:
# Downloading https://github.com/ultralytics/assets/releases/download/v8.3.0/yolo11n.pt to 'yolo11n.pt'...
# 100%|██████████| 5.35M/5.35M [00:03<00:00, 1.44MB/s]

# %% [markdown]
# https://huggingface.co/docs/transformers/en/model_doc/blip?usage=Pipeline

# %% [markdown]
# ## YOLO로 객체 분할하기

# %%
results = model("test_images/chair1.jpg")
boxes = results[0].boxes.xyxy.cpu().numpy()
# Out:
# image 1/1 /Users/brad/imagegenpoc/test_images/chair1.jpg: 640x288 2 chairs, 1 bed, 258.6ms
# Speed: 12.0ms preprocess, 258.6ms inference, 26.0ms postprocess per image at shape (1, 3, 640, 288)

# %%
boxes
# Out:
# array([[     104.88,      1205.4,      770.81,      2112.8],
#        [     254.33,      980.11,      1076.4,      1467.5],
#        [      1.354,      2091.2,      499.96,      2638.7]], dtype=float32)

# %% [markdown]
# ## 이미지 자르고 BLIP 프롬프트를 통한 레이블링

# %%
cropping_pipeline = pipeline(
    task="visual-question-answering",
    model="Salesforce/blip-vqa-base",
    torch_dtype=torch.float32,
    device='cpu'
)
url = "https://huggingface.co/datasets/huggingface/documentation-images/resolve/main/pipeline-cat-chonk.jpeg"
cropping_pipeline(question="What is the weather in this image?", image=url)
# Out:
# Device set to use cpu
# [{'answer': 'snowy'}]

# %% [markdown]
# ### BLIP 실행

# %%
import matplotlib.pyplot as plt

# %%
from PIL import Image
import matplotlib.pyplot as plt
import matplotlib.patches as patches

image = Image.open("test_images/chair1.jpg").convert("RGB")

# Create matplotlib figure and axes
fig, ax = plt.subplots(figsize=(10, 8))
ax.imshow(image)

for box in boxes:
    # Crop the image
    cropped = image.crop(box)

    # Get BLIP result
    result = cropping_pipeline(
        question="name the furniture in the image",
        image=cropped
    )
    label = result[0].get("answer", "unknown")

    # Draw box and label
    x1, y1, x2, y2 = box
    rect = patches.Rectangle(
        (x1, y1), x2 - x1, y2 - y1,
        linewidth=2, edgecolor="red", facecolor="none"
    )
    ax.add_patch(rect)
    ax.text(x1, y1 - 5, label, fontsize=12, color="white", backgroundcolor="red")

plt.axis("off")
plt.tight_layout()
plt.show()

# %%
cropping_pipeline = pipeline(
        task="visual-question-answering",

        model="Salesforce/blip-vqa-base",
        torch_dtype=torch.float16,
        device=0
        )
# Out:
# Device set to use cpu

# %%
# %du -sh ~/.cache/huggingface/transformers/models--Salesforce--blip-vqa-base
# Out:
# UsageError: Line magic function `%du` not found.
